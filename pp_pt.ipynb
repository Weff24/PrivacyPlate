# %% [markdown]
# <a href="https://colab.research.google.com/github/Weff24/PrivacyPlate/blob/main/pp_pt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data Extraction from XML Files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import xml.etree.ElementTree as ET
import os
import sys
from collections import defaultdict

from pathlib import Path
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import matplotlib.patches as patches
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image

# %%
# !pip install -U yolov5
# Out:
# Collecting yolov5
#   Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 11.6 MB/s eta 0:00:00
# Collecting gitpython>=3.1.30 (from yolov5)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 22.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from yolov5) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from yolov5) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from yolov5) (9.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from yolov5) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (1.11.3)
# Collecting thop>=0.1.1 (from yolov5)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.16.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (4.66.1)
# Collecting ultralytics>=8.0.100 (from yolov5)
#   Downloading ultralytics-8.0.203-py3-none-any.whl (644 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 51.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (2.14.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from yolov5) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from yolov5) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from yolov5) (67.7.2)
# Collecting fire (from yolov5)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting boto3>=1.19.1 (from yolov5)
#   Downloading boto3-1.28.75-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 12.1 MB/s eta 0:00:00
# Collecting sahi>=0.11.10 (from yolov5)
#   Downloading sahi-0.11.14-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 16.2 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.12.0 (from yolov5)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 34.6 MB/s eta 0:00:00
# Collecting roboflow>=0.2.29 (from yolov5)
#   Downloading roboflow-1.1.7-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# Collecting botocore<1.32.0,>=1.31.75 (from boto3>=1.19.1->yolov5)
#   Downloading botocore-1.31.75-py3-none-any.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 64.1 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.19.1->yolov5)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3>=1.19.1->yolov5)
#   Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.5 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->yolov5)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.12.0->yolov5) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->yolov5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->yolov5) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->yolov5) (2023.7.22)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->yolov5)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 16.8 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow>=0.2.29->yolov5)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 18.5 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib>=3.3->yolov5)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->yolov5)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.3 MB/s eta 0:00:00
# Collecting opencv-python-headless==4.8.0.74 (from roboflow>=0.2.29->yolov5)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.5 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3->yolov5)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.9 MB/s eta 0:00:00
# Collecting python-dotenv (from roboflow>=0.2.29->yolov5)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow>=0.2.29->yolov5) (1.16.0)
# Collecting supervision (from roboflow>=0.2.29->yolov5)
#   Downloading supervision-0.16.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 6.6 MB/s eta 0:00:00
# Collecting requests-toolbelt (from roboflow>=0.2.29->yolov5)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.11.10->yolov5) (2.0.2)
# Collecting pybboxes==0.1.6 (from sahi>=0.11.10->yolov5)
#   Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Collecting terminaltables (from sahi>=0.11.10->yolov5)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sahi>=0.11.10->yolov5) (8.1.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.5)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->yolov5) (3.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->yolov5) (2.1.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.0.100->yolov5) (9.0.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->yolov5) (2.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->yolov5) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->yolov5) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->yolov5) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->yolov5) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->yolov5) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->yolov5) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->yolov5) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=fef5f686739b984663fe32d18a66448e823aea28bc7b76417e93d490d2c4a9d6
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: terminaltables, smmap, python-dotenv, pyparsing, pybboxes, opencv-python-headless, jmespath, idna, fire, cycler, chardet, certifi, gitdb, botocore, thop, supervision, sahi, s3transfer, requests-toolbelt, huggingface-hub, gitpython, ultralytics, roboflow, boto3, yolov5
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed boto3-1.28.75 botocore-1.31.75 certifi-2022.12.7 chardet-4.0.0 cycler-0.10.0 fire-0.5.0 gitdb-4.0.11 gitpython-3.1.40 huggingface-hub-0.18.0 idna-2.10 jmespath-1.0.1 opencv-python-headless-4.8.0.74 pybboxes-0.1.6 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.1.7 s3transfer-0.7.0 sahi-0.11.14 smmap-5.0.1 supervision-0.16.0 terminaltables-3.1.10 thop-0.1.1.post2209072238 ultralytics-8.0.203 yolov5-7.0.13

# %% [markdown]
# # 1. Test XML Data Extraction: License Plate Crop Borders

# %%
# Path to annotation folder
annot_dir_path = Path("/content/drive/MyDrive/01-License Plates/annotations")

if not annot_dir_path.exists():
  print("Annotation directory path does not exist")
  sys.exit(1)

# Extract the box from xml files
box_locations = defaultdict(list)
box_sizes = defaultdict(list)
box_elements = ['xmin', 'ymin', "xmax", "ymax"] # order of the box location
box_size_elements = ['width', 'height'] # order of image size

for path in os.listdir(annot_dir_path):
    tree = ET.parse(f'{annot_dir_path}/{path}')  # Replace 'your_xml_file.xml' with your XML file path
    root = tree.getroot()

    # Get key from XML
    xml_ind =int(path[4:-4])

    for element in box_elements:
        box_locations[xml_ind].append(int(root.find('object').find('bndbox').find(element).text))

    for element in box_size_elements:
        box_sizes[xml_ind].append(int(root.find('size').find(element).text))

max_w = 0
max_h = 0
for w, h in box_sizes.values():
    if max_w < w:
        max_w = w
    if max_h < h:
        max_h = h

print('Max Width = ', max_w)
print('Max Height = ', max_h)
# Out:
# Max Width =  600
# Max Height =  531

# %% [markdown]
# # 2. Test License Plate Image Data Import

# %%
img_dir_path = Path("/content/drive/MyDrive/01-License Plates/paddedimages")

if not img_dir_path.exists():
  print("Image directory path does not exist")
  sys.exit(1)

images = []

i = 0
for i, path in enumerate(os.listdir(img_dir_path)):
  image = mpimg.imread(f"{img_dir_path}/{path}")
  fig, ax = plt.subplots()

  ax.imshow(image)

  # Red box around to see the license plate
  box = box_locations[int(path[4:-4])]
  rect = patches.Rectangle((box[0], box[1]), box[2] - box[0], box[3] - box[1], linewidth=1, edgecolor='r', facecolor='none')
  ax.add_patch(rect)

  plt.show()


  i += 1
  if i > 5:
    break

# %% [markdown]
# # 3. Preprocess Data

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split

# %%
class CarDataset(torch.utils.data.Dataset):
    def __init__(self, data_dir, transform=None):
        # Initialize your dataset here
        ############################# self.img_dir_path = data_dir + "/images"
        self.img_dir_path = data_dir + "/paddedimages"
        self.annot_dir_path = data_dir + "/annotations"
        self.transform = transform
        self.image_and_box = [set() for i in range(len(os.listdir(f"{self.img_dir_path}")))]
        self.box_elements = ['xmin', 'ymin', "xmax", "ymax"] # order of the box location
        self.box_size_elements = ['width', 'height']

        # populate image paths
        for path in os.listdir(self.img_dir_path):
            # Get box location info here
            tree = ET.parse(f'{self.annot_dir_path}/{path[:-4]}.xml')  # Replace 'your_xml_file.xml' with your XML file path
            root = tree.getroot()

            # Get key from XML
            xml_ind = int(path[4:-4])
            box_location = []
            box_sizes = []
            for element in self.box_elements:
                box_location.append(int(root.find('object').find('bndbox').find(element).text))

            for element in self.box_size_elements:
                box_sizes.append(int(root.find('size').find(element).text))

            # Add to image paths
            xml_ind = int(path[4:-4])
            self.image_and_box[xml_ind] = (f"{self.img_dir_path}/{path}", box_location, box_sizes)

    def __len__(self):
        # Return the number of samples in your dataset
        return len(self.image_and_box)

    def __getitem__(self, index):
        # Load and preprocess the data at the specified index
        image_path, label, size = self.image_and_box[index]
        return (image_path, label)

# %% [markdown]
# # 3. YOLO5 Model

# %%
# 1. Load Data
data_dir = "/content/drive/MyDrive/01-License Plates"

if not Path(data_dir).exists():
  print("Annotation directory path does not exist")
  sys.exit(1)

license_plates_dataset = CarDataset(data_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-18e914bf0231> in <cell line: 8>()
#       6   sys.exit(1)
#       7
# ----> 8 license_plates_dataset = CarDataset(data_dir)
#
# <ipython-input-5-83e222d41df3> in __init__(self, data_dir, transform)
#      13         for path in os.listdir(self.img_dir_path):
#      14             # Get box location info here
# ---> 15             tree = ET.parse(f'{self.annot_dir_path}/{path[:-4]}.xml')  # Replace 'your_xml_file.xml' with your XML file path
#      16             root = tree.getroot()
#      17
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in parse(source, parser)
#    1220     """
#    1221     tree = ElementTree()
# -> 1222     tree.parse(source, parser)
#    1223     return tree
#    1224
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in parse(self, source, parser)
#     578                     # It can be used to parse the whole source without feeding
#     579                     # it with chunks.
# --> 580                     self._root = parser._parse_whole(source)
#     581                     return self._root
#     582             while True:
#
# KeyboardInterrupt:

# %%
# license_plates_dataset[2]
import yolov5

# load model
model = yolov5.load('keremberke/yolov5m-license-plate')

# set model parameters
model.conf = 0.69  # NMS confidence threshold
model.iou = 0.45  # NMS IoU threshold
model.agnostic = False  # NMS class-agnostic
model.multi_label = False  # NMS multiple labels per box
model.max_det = 1000  # maximum number of detections per image

# %%
# set image
img = "/content/drive/MyDrive/01-License Plates/paddedimages/Cars207.png"

# perform inference
results = model(img, size=640)

# inference with test time augmentation
results = model(img, augment=True)

# parse results
predictions = results.pred[0]
boxes = predictions[:, :4] # x1, y1, x2, y2
scores = predictions[:, 4]
categories = predictions[:, 5]

# show detection bounding boxes on image
results.show()

# save results into "results/" folder
results.save(save_dir='results/')
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>
# Saved 1 image to results5

# %%
# we draw stuff
fig, ax = plt.subplots()
image = mpimg.imread(img)

ax.imshow(image)
box = boxes[0]
# x1, y1, x2, y2
# Red box around to see the license plate
#box = box_locations[int(path[4:-4])]
# rect = patches.Rectangle((box[0], box[1]), box[2] - box[0], box[3] - box[1], linewidth=1, edgecolor='r', facecolor='none')
# ax.add_patch(rect)

plt.show()
# Out:
# <ipython-input-33-5de45d6a7665>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()

# %%
# we draw stuff
fig, ax = plt.subplots()
image = mpimg.imread(img)

ax.imshow(image)
box = boxes[0]
# x1, y1, x2, y2
# Red box around to see the license plate
#box = box_locations[int(path[4:-4])]
rect = patches.Rectangle((box[0], box[1]), box[2] - box[0], box[3] - box[1], linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(rect)

plt.show()

# %% [markdown]
# # 4. Testing YOLO5

# %%
loss = 0
images_limits = 100
images_processed = 0

# Loop through all data points
for i, data in enumerate(license_plates_dataset):
  # 10 images limit
  if i > images_limits:
    break

  image, box = data

  # perform inference
  results = model(image, size=640)

  # inference with test time augmentation
  results = model(image, augment=True)

  # parse results
  predictions = results.pred[0]
  boxes = predictions[:, :4] # x1, y1, x2, y2
  processed_box = boxes[0]

  # add loss
  for i in range(len(processed_box)):
    loss += abs(processed_box[i] - box[i])

  images_processed += 1

# Loss
print("Pixel Differences: ", loss/images_processed)
# Out:
# Pixel Differences:  tensor(22.41912)
